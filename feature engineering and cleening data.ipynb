# %%
import pandas as pd
import numpy as np

# %%
Calories = pd.read_csv("C:/Users/SMK/Desktop/log file/Colleted file2/Fitabase Data 4.12.16-5.12.16/minute base Narrow/minuteCaloriesNarrow_merged.csv")

# %%
Intensity = pd.read_csv("C:/Users/SMK/Desktop/log file/Colleted file2/Fitabase Data 4.12.16-5.12.16/minute base Narrow/minuteIntensitiesNarrow_merged.csv")

# %%
MET = pd.read_csv("C:/Users/SMK/Desktop/log file/Colleted file2/Fitabase Data 4.12.16-5.12.16/minute base Narrow/minuteMETsNarrow_merged.csv")

# %%
Step = pd.read_csv("C:/Users/SMK/Desktop/log file/Colleted file2/Fitabase Data 4.12.16-5.12.16/minute base Narrow/minuteStepsNarrow_merged.csv")

# %%
Calories
# Out:
#                  Id         ActivityMinute  Calories
# 0        1503960366  4/12/2016 12:00:00 AM   0.78650
# 1        1503960366  4/12/2016 12:01:00 AM   0.78650
# 2        1503960366  4/12/2016 12:02:00 AM   0.78650
# 3        1503960366  4/12/2016 12:03:00 AM   0.78650
# 4        1503960366  4/12/2016 12:04:00 AM   0.78650
# ...             ...                    ...       ...
# 1325575  8877689391   5/12/2016 1:55:00 PM   1.33353
# 1325576  8877689391   5/12/2016 1:56:00 PM   1.33353
# 1325577  8877689391   5/12/2016 1:57:00 PM   1.33353
# 1325578  8877689391   5/12/2016 1:58:00 PM   1.33353
# 1325579  8877689391   5/12/2016 1:59:00 PM   1.33353
#
# [1325580 rows x 3 columns]

# %%
Calories['DATE_TIME']=pd.to_datetime(Calories["ActivityMinute"])
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\1366958933.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Calories['DATE_TIME']=pd.to_datetime(Calories["ActivityMinute"])

# %%
Intensity
# Out:
#                  Id         ActivityMinute  Intensity
# 0        1503960366  4/12/2016 12:00:00 AM          0
# 1        1503960366  4/12/2016 12:01:00 AM          0
# 2        1503960366  4/12/2016 12:02:00 AM          0
# 3        1503960366  4/12/2016 12:03:00 AM          0
# 4        1503960366  4/12/2016 12:04:00 AM          0
# ...             ...                    ...        ...
# 1325575  8877689391   5/12/2016 1:55:00 PM          0
# 1325576  8877689391   5/12/2016 1:56:00 PM          0
# 1325577  8877689391   5/12/2016 1:57:00 PM          0
# 1325578  8877689391   5/12/2016 1:58:00 PM          0
# 1325579  8877689391   5/12/2016 1:59:00 PM          0
#
# [1325580 rows x 3 columns]

# %%
Intensity["DATE_TIME"]=pd.to_datetime(Intensity["ActivityMinute"])
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\4047754590.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Intensity["DATE_TIME"]=pd.to_datetime(Intensity["ActivityMinute"])

# %%
MET
# Out:
#                  Id         ActivityMinute  METs
# 0        1503960366  4/12/2016 12:00:00 AM    10
# 1        1503960366  4/12/2016 12:01:00 AM    10
# 2        1503960366  4/12/2016 12:02:00 AM    10
# 3        1503960366  4/12/2016 12:03:00 AM    10
# 4        1503960366  4/12/2016 12:04:00 AM    10
# ...             ...                    ...   ...
# 1325575  8877689391   5/12/2016 1:55:00 PM    11
# 1325576  8877689391   5/12/2016 1:56:00 PM    11
# 1325577  8877689391   5/12/2016 1:57:00 PM    11
# 1325578  8877689391   5/12/2016 1:58:00 PM    11
# 1325579  8877689391   5/12/2016 1:59:00 PM    11
#
# [1325580 rows x 3 columns]

# %%
MET["DATE_TIME"]=pd.to_datetime(MET["ActivityMinute"])
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3340157617.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   MET["DATE_TIME"]=pd.to_datetime(MET["ActivityMinute"])

# %%
Step
# Out:
#                  Id         ActivityMinute  Steps
# 0        1503960366  4/12/2016 12:00:00 AM      0
# 1        1503960366  4/12/2016 12:01:00 AM      0
# 2        1503960366  4/12/2016 12:02:00 AM      0
# 3        1503960366  4/12/2016 12:03:00 AM      0
# 4        1503960366  4/12/2016 12:04:00 AM      0
# ...             ...                    ...    ...
# 1325575  8877689391   5/12/2016 1:55:00 PM      0
# 1325576  8877689391   5/12/2016 1:56:00 PM      0
# 1325577  8877689391   5/12/2016 1:57:00 PM      0
# 1325578  8877689391   5/12/2016 1:58:00 PM      0
# 1325579  8877689391   5/12/2016 1:59:00 PM      0
#
# [1325580 rows x 3 columns]

# %%
Step["DATE_TIME"]=pd.to_datetime(Step["ActivityMinute"])
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\2753419412.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Step["DATE_TIME"]=pd.to_datetime(Step["ActivityMinute"])

# %%
Calories.drop("ActivityMinute",axis=1,inplace=True)

# %%
Step.drop("ActivityMinute",axis=1,inplace=True)

# %%
Intensity.drop("ActivityMinute",axis=1,inplace=True)

# %%
MET.drop("ActivityMinute",axis=1,inplace=True)

# %%
from functools import reduce
df_total = [Intensity,Step,MET,Calories]
merged_df=reduce(lambda left , right :pd.merge(left,right,on=['Id','DATE_TIME'],how='inner'),df_total)

# %%
merged_df
# Out:
#                  Id  Intensity           DATE_TIME  Steps  METs  Calories
# 0        1503960366          0 2016-04-12 00:00:00      0    10   0.78650
# 1        1503960366          0 2016-04-12 00:01:00      0    10   0.78650
# 2        1503960366          0 2016-04-12 00:02:00      0    10   0.78650
# 3        1503960366          0 2016-04-12 00:03:00      0    10   0.78650
# 4        1503960366          0 2016-04-12 00:04:00      0    10   0.78650
# ...             ...        ...                 ...    ...   ...       ...
# 1325575  8877689391          0 2016-05-12 13:55:00      0    11   1.33353
# 1325576  8877689391          0 2016-05-12 13:56:00      0    11   1.33353
# 1325577  8877689391          0 2016-05-12 13:57:00      0    11   1.33353
# 1325578  8877689391          0 2016-05-12 13:58:00      0    11   1.33353
# 1325579  8877689391          0 2016-05-12 13:59:00      0    11   1.33353
#
# [1325580 rows x 6 columns]

# %%
df = merged_df[merged_df["Steps"]!=0]

# %%
df.shape
# Out:
# (199910, 6)

# %%
df["Weight"]=((200*df.Calories)/(3.5*df.METs))*10
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\595752909.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Weight"]=((200*df.Calories)/(3.5*df.METs))*10

# %%
df["MET"]=df.METs/10
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3453708609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MET"]=df.METs/10

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
sns.heatmap(corr,annot=True,fmt='.2f',cmap='Blues')
plt.plot()
# Out:
# []

# %%
df
# Out:
#                  Id  Intensity           DATE_TIME  Steps  METs  Calories  \
# 25       1503960366          1 2016-04-12 00:25:00      7    26   2.04490
# 29       1503960366          1 2016-04-12 00:29:00     32    32   2.51680
# 34       1503960366          1 2016-04-12 00:34:00     41    36   2.83140
# 35       1503960366          1 2016-04-12 00:35:00     29    32   2.51680
# 36       1503960366          1 2016-04-12 00:36:00      8    26   2.04490
# ...             ...        ...                 ...    ...   ...       ...
# 1325555  8877689391          1 2016-05-12 13:35:00     88    42   5.09166
# 1325556  8877689391          1 2016-05-12 13:36:00     85    54   6.54642
# 1325557  8877689391          1 2016-05-12 13:37:00     96    74   8.97102
# 1325558  8877689391          1 2016-05-12 13:38:00      9    30   3.63690
# 1325564  8877689391          1 2016-05-12 13:44:00     14    28   3.39444
#
#             Weight  MET
# 25       44.942856  2.6
# 29       44.942856  3.2
# ...

# %%
df.drop("METs",axis=1,inplace=True)
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3781447839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("METs",axis=1,inplace=True)

# %%
MET=df[["MET"]]
df.drop("MET",axis=1,inplace=True)
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3503093429.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("MET",axis=1,inplace=True)

# %%
Weight=df[["Weight"]]
df.drop("Weight",axis=1,inplace=True)
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3830093945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("Weight",axis=1,inplace=True)

# %%
DATE_TIME=df[["DATE_TIME"]]
df.drop("DATE_TIME",axis=1,inplace=True)
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\1717589660.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("DATE_TIME",axis=1,inplace=True)

# %%
Calories=df[["Calories"]]
df.drop("Calories",axis=1,inplace=True)
# Out:
# C:\Users\SMK\AppData\Local\Temp\ipykernel_11452\3516936162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("Calories",axis=1,inplace=True)

# %%
df
# Out:
#                  Id  Intensity  Steps
# 25       1503960366          1      7
# 29       1503960366          1     32
# 34       1503960366          1     41
# 35       1503960366          1     29
# 36       1503960366          1      8
# ...             ...        ...    ...
# 1325555  8877689391          1     88
# 1325556  8877689391          1     85
# 1325557  8877689391          1     96
# 1325558  8877689391          1      9
# 1325564  8877689391          1     14
#
# [199910 rows x 3 columns]

# %%
df=pd.concat([df,MET,Weight,DATE_TIME,Calories],axis=1)

# %%
df
# Out:
#                  Id  Intensity  Steps  MET     Weight           DATE_TIME  \
# 25       1503960366          1      7  2.6  44.942856 2016-04-12 00:25:00
# 29       1503960366          1     32  3.2  44.942856 2016-04-12 00:29:00
# 34       1503960366          1     41  3.6  44.942856 2016-04-12 00:34:00
# 35       1503960366          1     29  3.2  44.942856 2016-04-12 00:35:00
# 36       1503960366          1      8  2.6  44.942856 2016-04-12 00:36:00
# ...             ...        ...    ...  ...        ...                 ...
# 1325555  8877689391          1     88  4.2  69.274286 2016-05-12 13:35:00
# 1325556  8877689391          1     85  5.4  69.274287 2016-05-12 13:36:00
# 1325557  8877689391          1     96  7.4  69.274284 2016-05-12 13:37:00
# 1325558  8877689391          1      9  3.0  69.274285 2016-05-12 13:38:00
# 1325564  8877689391          1     14  2.8  69.274284 2016-05-12 13:44:00
#
#          Calories
# 25        2.04490
# 29        2.51680
# 34        2.83140
# ...

# %%
df.to_csv("Calories_final_2.csv")
